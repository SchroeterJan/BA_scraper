# %%
import os
import pandas as pd

# %%
print(os.getcwd())
# Out:
# c:\Users\damon\Documents\python\Projekte\TI\AW_scraper

# %%
parl_period = pd.read_excel(os.path.join("files/parliament_period.xlsx"))

# %%
parl_period
# Out:
#     Unnamed: 0     id        entity_type  \
# 0            0  63289  candidacy_mandate
# 1            1  63287  candidacy_mandate
# 2            2  63286  candidacy_mandate
# 3            3  63285  candidacy_mandate
# 4            4  63284  candidacy_mandate
# ..         ...    ...                ...
# 95          95  63172  candidacy_mandate
# 96          96  63171  candidacy_mandate
# 97          97  63170  candidacy_mandate
# 98          98  63169  candidacy_mandate
# 99          99  63168  candidacy_mandate
#
#                                          label  \
# 0     Hans-Peter Goetz (Brandenburg Wahl 2024)
# 1       Andreas Gliese (Brandenburg Wahl 2024)
# 2      Manfred Mießner (Brandenburg Wahl 2024)
# 3   Eleonore Mühlbauer (Thüringen 2019 - 2024)
# 4      Robert Hanschke (Brandenburg Wahl 2024)
# ..                                         ...
# 95  Michaela Schreiber (Brandenburg Wahl 2024)
# 96      Jens Wylegalla (Brandenburg Wahl 2024)
# ...

# %%
parl_period.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 16 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   Unnamed: 0                              100 non-null    int64
#  1   id                                      100 non-null    int64
#  2   entity_type                             100 non-null    object
#  3   label                                   100 non-null    object
#  4   api_url                                 100 non-null    object
#  5   id_external_administration              0 non-null      float64
#  6   id_external_administration_description  0 non-null      float64
#  7   type                                    100 non-null    object
#  8   parliament_period                       0 non-null      float64
#  9   politician                              0 non-null      float64
# ...
